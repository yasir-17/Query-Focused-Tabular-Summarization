# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import datasets
train_df = datasets.load_from_disk("data/train")
test_df = datasets.load_from_disk("data/test")
validate_df = datasets.load_from_disk("data/validate")
validate_decomposed = datasets.load_from_disk("data/decomposed_validate")

# %%
import pandas as pd

def to_pandas(item):
  return pd.DataFrame(item['table']["rows"],columns=item['table']["header"])


item = train_df[919]
to_pandas(item)
# Out:
#    Class        Type                                      Fleet Numbers  \
# 0     Pp   4 - 4 - 0  12 , 25 , 42 - 46 , 50 , 70 - 71 , 74 - 77 , 1...
# 1     Pg   0 - 6 - 0                           10 - 11 , 78 , 100 - 103
# 2      Q   4 - 4 - 0                              120 - 125 , 130 - 136
# 3     Qg   0 - 6 - 0                                          152 - 155
# 4      P   4 - 4 - 0                                88 - 89 , 104 - 105
# 5     Ql   4 - 4 - 0             24 , 113 - 114 , 126 - 128 , 156 - 157
# 6    Qgt  0 - 6 - 2T                                            98 - 99
# 7    Lqg   0 - 6 - 0                   78 , 108 , 110 - 111 , 158 - 164
# 8     Rt  0 - 6 - 4T                                22 - 23 , 166 - 167
# 9    Nqg   0 - 6 - 0                            9 , 38 - 39 , 109 , 112
# 10  Nlqg   0 - 6 - 0                                                165
# 11  Qgt2  0 - 6 - 2T                                          168 - 169
# 12     S   4 - 4 - 0                                          170 - 174
# 13    Sg   0 - 6 - 0                           37 , 40 - 41 , 137 - 138
#
#    Quantity Made    Date Made 1958 Cié 1958 Uta Date Withdrawn
# 0             17  1896 - 1911        5        7    1957 - 1963
# 1              7  1899 - 1904        0        7    1960 - 1964
# 2             13  1899 - 1904        5        4    1951 - 1963
# 3              4  1903 - 1904        4        0    1962 - 1963
# 4              4  1904 - 1906        1        0    1956 - 1960
# 5              8  1904 - 1910        0        3    1932 - 1960
# 6              2         1905        1        0    1957 - 1960
# 7             11  1906 - 1908        6        5    1958 - 1963
# 8              4  1908 - 1911        0        4    1958 - 1963
# 9              5         1911        2        3    1958 - 1963
# 10             1         1911        0        1           1961
# 11             2         1911        -        -           1957
# 12             5         1913        3        2    1964 - 1965
# 13             5         1913        3        2    1961 - 1965

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model_path = "omnitab"
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
from typing import Dict
import pandas as pd

def tokenization_with_answer(examples):
    tables_query_answers = [[],[],[]]

    for table, query, summary in zip(examples['table'], examples['query'], examples['summary']):
        try:
            tables_query_answers[0].append(pd.DataFrame(table['rows'], columns=table['header']))
            tables_query_answers[1].append(query)
            tables_query_answers[2].append(summary)
        except:
            continue
    
    model_inputs = tokenizer(tables_query_answers[0], tables_query_answers[1], padding=True, truncation=True, max_length=1024)
    model_inputs['labels'] = tokenizer(answer=tables_query_answers[2], padding=True, truncation=True, max_length=128)["input_ids"] 
    
    return model_inputs

tokenized_dataset_train = train_df.map(tokenization_with_answer, batched=True)
tokenized_dataset_test = test_df.map(tokenization_with_answer, batched=True)

processed_data_train = tokenized_dataset_train.remove_columns(['table','summary', 'row_ids', 'example_id', 'query'])
processed_data_test = tokenized_dataset_test.remove_columns(['table','summary', 'row_ids', 'example_id', 'query'])
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
processed_data_train
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 2000
# })

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq

def postprocess_text(preds, labels):
        preds = [pred.strip() for pred in preds]
        labels = [label.strip() for label in labels]

        # rougeLSum expects newline after each sentence
        preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]
        labels = ["\n".join(nltk.sent_tokenize(label)) for label in labels]

        return preds, labels

def metric_fn(eval_predictions):
    predictions, labels = eval_predictions
    decoded_predictions = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    for label in labels:
        label[label < 0] = tokenizer.pad_token_id  # Replace masked label tokens
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    decoded_predictions, decoded_labels = postprocess_text(decoded_predictions, decoded_labels)

    rouge = evaluate.load('rouge')

    # Compute ROUGE scores
    rouge_results = rouge.compute(predictions=decoded_predictions, references=decoded_labels)

    return rouge_results

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model= model)

train_args = Seq2SeqTrainingArguments(
    output_dir="./train_weight_omnitab",
    learning_rate=3e-5,
    per_device_train_batch_size=22,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    evaluation_strategy="epoch",
    save_strategy = "epoch",
    weight_decay=0.01,
    save_total_limit=5,
    warmup_ratio=0.03,
    load_best_model_at_end=True,
    predict_with_generate=True,
    overwrite_output_dir= True,
    gradient_accumulation_steps = 2
)


trainer = Seq2SeqTrainer(
    model,
    train_args,
    train_dataset=processed_data_train,
    eval_dataset=processed_data_test,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=metric_fn
)
# Out:
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %%
from datasets import concatenate_datasets
import nltk
import evaluate

trainer.train()
# Out:
#     <div>
#
#       <progress value='450' max='450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [450/450 1:02:03, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>1.089619</td>
#       <td>0.439336</td>
#       <td>0.221206</td>
#       <td>0.334017</td>
#       <td>0.395413</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.949296</td>
#       <td>0.491683</td>
#       <td>0.256243</td>
#       <td>0.377304</td>
#       <td>0.443681</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.971320</td>
#       <td>0.504575</td>
#       <td>0.265964</td>
#       <td>0.390490</td>
#       <td>0.453104</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.999437</td>
#       <td>0.499697</td>
#       <td>0.258538</td>
#       <td>0.385561</td>
#       <td>0.447707</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.029502</td>
#       <td>0.498271</td>
#       <td>0.259015</td>
#       <td>0.385963</td>
#       <td>0.445935</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.046886</td>
#       <td>0.497940</td>
#       <td>0.257966</td>
#       <td>0.384935</td>
#       <td>0.446054</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=450, training_loss=0.8654727511935764, metrics={'train_runtime': 3778.0564, 'train_samples_per_second': 5.294, 'train_steps_per_second': 0.119, 'total_flos': 3.717603609005261e+16, 'train_loss': 0.8654727511935764, 'epoch': 9.89})

# %%
validate_df = datasets.load_from_disk("data/validate")
validate_df_size = len(validate_df)
step_size = 3
num_batches = validate_df_size // step_size

valid = []

for i in range(num_batches):
    start_index = i * step_size
    end_index = (i + 1) * step_size
    valid.append(validate_df.select(range(start_index, end_index)))

# If there are remaining data points that don't fit into full batches of size 3
if validate_df_size % step_size != 0:
    remaining_data = validate_df_size % step_size
    valid.append(validate_df.select(range(validate_df_size - remaining_data, validate_df_size)))

# %%
import numpy as np
rougeL = []
bert = []
# bertscore = evaluate.load("bertscore")

for i in range(len(valid)):
    validate_df = valid[i].map(tokenization_with_answer, batched=True)
    predict_results = trainer.predict(validate_df, max_length = 1024)
    metrics = predict_results.metrics
    predictions = tokenizer.batch_decode(predict_results.predictions, skip_special_tokens=True, clean_up_tokenization_spaces=True)
    predictions = [pred.strip() for pred in predictions]
    
    # bert_score = bertscore.compute(predictions=predictions, references=valid[i]['summary'], lang = "en")
    rougeL.append(metrics['test_rougeLsum'])
    # bert.append(np.mean(bert_score['f1']))

sum(rougeL)/len(rougeL)
# Out:
# Map: 100%|██████████| 3/3 [00:00<00:00,  3.12 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 21.17 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 48.33 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 53.45 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  9.43 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 52.52 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  3.01 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  9.26 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 49.56 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 55.14 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 40.31 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 50.82 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 64.15 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 34.63 examples/s]
# Map: 100%|██████████| 3/3 [00:01<00:00,  2.25 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  4.30 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 38.80 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 34.94 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 40.67 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.43 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.33 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 23.74 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 76.30 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.54 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 101.45 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 35.08 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 53.94 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 55.33 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 30.13 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 108.97 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 95.27 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 54.80 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 24.17 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 71.18 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 64.64 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 45.81 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 62.16 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.46 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.05 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 57.09 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 74.85 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 24.04 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 47.10 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 50.83 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 48.12 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  3.25 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 51.27 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 58.28 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 52.92 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 58.58 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 50.51 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 48.13 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 57.36 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 76.96 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 44.92 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 67.91 examples/s]
# Map: 100%|██████████| 3/3 [00:01<00:00,  2.48 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 42.25 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  8.41 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 56.04 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  9.27 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 60.27 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 36.81 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 45.78 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00, 43.94 examples/s]
# Map: 100%|██████████| 3/3 [00:00<00:00,  5.94 examples/s]
# Map: 100%|██████████| 2/2 [00:00<00:00, 34.79 examples/s]
# 0.4427862668790004

# %%
trainer.save_model("omnitab")

# %%
validate_df = datasets.load_from_disk("data/validate")
tokenized_dataset_validate = validate_df.map(tokenization_with_answer, batched=True)
processed_data_validate = tokenized_dataset_validate.remove_columns(['table', 'summary', 'row_ids', 'example_id', 'query'])
from torch.utils.data import DataLoader

validation_dataloader = DataLoader(
    processed_data_validate,
    batch_size=8,  # You can adjust this
    collate_fn=data_collator
)

import torch
from tqdm import tqdm
import nltk
import evaluate
from datasets import concatenate_datasets

model.eval()
all_predictions = []

with torch.no_grad():
    for batch in tqdm(validation_dataloader):
        # Move batch to the same device as the model
        batch = {k: v.to(model.device) for k, v in batch.items()}
        
        # Generate predictions
        outputs = model.generate(
            input_ids=batch['input_ids'],
            attention_mask=batch['attention_mask'],
            max_length=128  # Adjust as needed
        )
        
        # Decode predictions
        decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        all_predictions.extend(decoded_preds)

# Post-process predictions
processed_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in all_predictions]

# Get the reference summaries
reference_summaries = validate_df['summary']
processed_refs = ["\n".join(nltk.sent_tokenize(ref.strip())) for ref in reference_summaries]

# Compute metrics
rouge = evaluate.load('rouge')
rouge_results = rouge.compute(predictions=processed_preds, references=processed_refs)

print(rouge_results)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# 100%|██████████| 25/25 [01:06<00:00,  2.65s/it]
# {'rouge1': 0.4900054344390593, 'rouge2': 0.25062032256417055, 'rougeL': 0.37390804497694863, 'rougeLsum': 0.4404926774885889}

# %%
validate_decomposed = datasets.load_from_disk("data/decomposed_validate")
tokenized_dataset_validate_decomposed = validate_decomposed.map(tokenization_with_answer, batched=True)
processed_data_validate_decomposed = tokenized_dataset_validate_decomposed.remove_columns(['table', 'summary', 'row_ids', 'example_id', 'query'])
from torch.utils.data import DataLoader

validation_dataloader = DataLoader(
    processed_data_validate_decomposed,
    batch_size=8,  # You can adjust this
    collate_fn=data_collator
)

import torch
from tqdm import tqdm

model.eval()
decomposed_predictions = []

with torch.no_grad():
    for batch in tqdm(validation_dataloader):
        # Move batch to the same device as the model
        batch = {k: v.to(model.device) for k, v in batch.items()}
        
        # Generate predictions
        outputs = model.generate(
            input_ids=batch['input_ids'],
            attention_mask=batch['attention_mask'],
            max_length=128  # Adjust as needed
        )
        
        # Decode predictions
        decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        decomposed_predictions.extend(decoded_preds)

# Post-process predictions
processed_preds_decomposed = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decomposed_predictions]

# Get the reference summaries
reference_summaries = validate_df['summary']
processed_refs = ["\n".join(nltk.sent_tokenize(ref.strip())) for ref in reference_summaries]

# Compute metrics
rouge = evaluate.load('rouge')
rouge_results = rouge.compute(predictions=processed_preds_decomposed, references=processed_refs)

print(rouge_results)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# 100%|██████████| 25/25 [00:31<00:00,  1.28s/it]
# {'rouge1': 0.4929236370177368, 'rouge2': 0.2556142155252692, 'rougeL': 0.37678567786803, 'rougeLsum': 0.4437173395736421}

# %%
import numpy as np
bertscore = evaluate.load("bertscore")
bert = []
bert_score = bertscore.compute(predictions=processed_preds_decomposed, references=processed_refs, lang = "en")
bert.append(np.mean(bert_score['f1']))
np.average(bert)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0.9015538358688354

# %%
bertscore = evaluate.load("bertscore")
bert = []
bert_score = bertscore.compute(predictions=processed_preds, references=processed_refs, lang = "en")
bert.append(np.mean(bert_score['f1']))
import numpy as np
np.average(bert)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0.900832970738411

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# Initialize a tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Function to calculate the number of tokens in a table's markdown format
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Function to calculate the number of tokens in a table's markdown format
def count_tokens_in_markdown(df):
    markdown = df.to_markdown(index=False)
    return len(tokenizer.tokenize(markdown))

# List to store differences in token counts for each entry
token_differences = []
token_dfs = []
token_decomposeds = []

# Assume both datasets have the same number of entries
for item_df, item_decomposed in zip(validate_df, validate_decomposed):
    # Convert to DataFrames
    df_1 = to_pandas(item_df)
    df_2 = to_pandas(item_decomposed)
    
    # Calculate token counts
    tokens_df = count_tokens_in_markdown(df_1)
    tokens_decomposed = count_tokens_in_markdown(df_2)
    
    # Calculate the difference and store it
    token_differences.append(abs(tokens_df - tokens_decomposed))
    
    token_dfs.append(tokens_df)
    token_decomposeds.append(tokens_decomposed)

# Calculate the average difference across all entries
average_difference = sum(token_differences) / len(token_differences)

print(f"Average difference in number of tokens across all entries: {average_difference}")
print(np.mean(token_dfs))
print(np.mean(token_decomposeds))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (531 > 512). Running this sequence through the model will result in indexing errors
# Average difference in number of tokens across all entries: 39.98
# 450.875
# 416.095

# %%
from rouge_score import rouge_scorer
scorer = rouge_scorer.RougeScorer(['rougeLsum'], use_stemmer=True)

rouge_scores_decomposed = []
for pred, ref in zip(processed_preds_decomposed, processed_refs):
    score = scorer.score(ref, pred)
    rouge_scores_decomposed.append(score['rougeLsum'].fmeasure)


rouge_scores = []
for pred, ref in zip(processed_preds, processed_refs):
    score = scorer.score(ref, pred)
    rouge_scores.append(score['rougeLsum'].fmeasure)
    
print(np.average(rouge_scores_decomposed))
print(np.average(rouge_scores))
# Out:
# 0.46026598461125856
# 0.45748969297451986

# %%
import random

random_indices = random.sample(range(200), 100)

for i in random_indices:
    example = validate_df[i]
    df = to_pandas(example)
    query = example['query']
    generated_summary = decomposed_predictions[i]
    expected_summary = reference_summaries[i]
    
    # Calculate ROUGE score
    score = scorer.score(expected_summary, generated_summary)


    # Print results
    print(f"Index: {i}")
    print(df.to_markdown())
    print(f"Query: {query}")
    print("\n")
    print(f"Generated Summary: {generated_summary}")
    print("\n")
    print(f"Expected Summary: {expected_summary}")
    print("--" * 50)
    print("\n")
# Out:
# Index: 129
# |    | Team                        |   Wins |   Losses |   Percentage | Home   | Away   | Streak   |
# |---:|:----------------------------|-------:|---------:|-------------:|:-------|:-------|:---------|
# |  0 | Louisiana Swashbucklers     |     13 |        1 |        0.928 | 7 - 0  | 6 - 1  | Lost 1   |
# |  1 | Corpus Christi Hammerheads  |     12 |        2 |        0.857 | 6 - 1  | 6 - 1  | Won 4    |
# |  2 | Frisco Thunder              |      8 |        6 |        0.572 | 4 - 3  | 4 - 3  | Lost 3   |
# |  3 | Odessa Roughnecks           |      8 |        6 |        0.572 | 5 - 2  | 3 - 4  | Won 2    |
# |  4 | Katy Ruff Riders            |      7 |        7 |        0.5   | 4 - 3  | 3 - 4  | Won 1    |
# |  5 | San Angelo Stampede Express |      4 |       10 |        0.286 | 3 - 4  | 1 - 6  | Lost 1   |
# |  6 | Centex Barracudas           |      2 |       12 |        0.143 | 1 - 6  | 1 - 6  | Lost 3   |
# |  7 | Alaska Wild                 |      2 |       12 |        0.143 | 2 - 5  | 0 - 7  | Won 2    |
# Query: Summarize the teams with a winning streak in the 2007 Intense Football League season.
#
#
# Generated Summary: The 2007 Intense Football League season saw four teams with winning streaks. The Corpus Christi Hammerheads had the longest winning streak with 12 wins, 2 losses, and a 0.857 winning percentage. The Odessa Roughnecks followed with 8 wins, 6 losses, a 0
#
#
# Expected Summary: In the 2007 Intense Football League Season, Katy Ruff Riders had a winning streak. They had a 7-7 record with a 4-3 home record and 3-4 away record.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 68
# |    |   # | Date     | Visitor    | Score   | Home       | OT   | Decision   | Attendance   | Series   |
# |---:|----:|:---------|:-----------|:--------|:-----------|:-----|:-----------|:-------------|:---------|
# |  0 |   1 | April 26 | Ottawa     | 5 – 4   | New Jersey |      | Brodeur    | 15,512       | 0 – 1    |
# |  1 |   2 | April 28 | Ottawa     | 2 – 3   | New Jersey | 2OT  | Brodeur    | 19,040       | 1 – 1    |
# |  2 |   3 | April 30 | New Jersey | 0 – 2   | Ottawa     |      | Brodeur    | 19,636       | 1 – 2    |
# |  3 |   4 | May 2    | New Jersey | 2 – 3   | Ottawa     |      | Brodeur    | 20,248       | 1 – 3    |
# |  4 |   5 | May 5    | Ottawa     | 3 – 2   | New Jersey |      | Brodeur    | 19,040       | 1 – 4    |
# Query: Who made the decision for each game in the series, and is there a correlation between the decisions made and the outcomes of the games?
#
#
# Generated Summary: In the series, the decision made by the officials for each game was make by Martin Brodeur. In Game 1, Brodear make the decision, and the game ended with a 5-4 win for Ottawa. In game 2, Broadeur make the same decision, but the game was tied at 1-1. In the Game 3, Broadle make the final decision, which ended with the loss for New Jersey.
#
#
# Expected Summary: In the 2006-07 New Jersey Devils East Conference Semi-finals series play against Ottawa Senators, Brodeur make decision for all five games. Outcome of games not seem strong related with Brodeur's decisions as Devils only win one game in series (Game 2). Overall, Ottawa Senators take series with 4-1 victory, beat New Jersey Devils in most of matchups.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 0
# |    | Player                      |   Games Played |   Minutes |   Field Goals |   Three Pointers |   Free Throws |   Rebounds |   Assists |   Blocks |   Steals |   Points |
# |---:|:----------------------------|---------------:|----------:|--------------:|-----------------:|--------------:|-----------:|----------:|---------:|---------:|---------:|
# |  0 | Moore Maya Moore            |             39 |      1209 |           284 |               90 |            96 |        348 |       127 |       59 |       76 |      754 |
# |  1 | Montgomery Renee Montgomery |             39 |      1237 |           226 |               99 |            93 |         82 |       199 |        9 |       61 |      644 |
# |  2 | Charles Tina Charles        |             39 |       982 |           259 |                0 |           124 |        348 |        41 |       62 |       35 |      642 |
# |  3 | Greene Kalana Greene        |             39 |       990 |           141 |                6 |            50 |        181 |        68 |       11 |       37 |      338 |
# |  4 | Doty Caroline Doty          |             17 |       406 |            52 |               30 |            13 |         57 |        33 |        4 |       16 |      147 |
# |  5 | Hayes Tiffany Hayes         |             39 |      1002 |           109 |               46 |            63 |        156 |       102 |       15 |       44 |      327 |
# |  6 | Mclaren Kaili Mclaren       |             38 |       581 |            61 |                0 |            37 |        130 |        73 |       22 |       19 |      159 |
# |  7 | Williams Tahirah Williams   |             33 |       245 |            33 |                0 |            22 |         62 |        22 |        4 |        9 |       88 |
# |  8 | Dixon Lorin Dixon           |             39 |       604 |            28 |                2 |            31 |         63 |        71 |        2 |       17 |       89 |
# |  9 | Gardler Meghan Gardler      |             32 |       335 |            19 |                5 |            15 |         62 |        21 |        3 |       12 |       58 |
# | 10 | Fernandes Jacquie Fernandes |             30 |       141 |             8 |                3 |             4 |         17 |         2 |        0 |        3 |       23 |
# Query: Which player(s) scored more than 600 points in the 2008 - 09 Connecticut Huskies Women's Basketball Team? Summarize the basic information of these players.
#
#
# Generated Summary: The 2008 - 09 Connecticut Huskies Women's Basketball Team had three players who scored more than 600 points. Maya Moore scored 754 points, Montgomery Renee Montgomery scored 644 points, and Charles Tina Charles scored 642 points. Moore played 39 minutes and shot 284 field goals, 90 three-pointers, 96 free throws, and had 348 rebounds. Montgomery played 39 games and shot 226 field goals and had 99 free throws. She had 199 rebounds and 61 assists. Lastly, Charles TinaCharles played 39 game and shot 259 field goals with 124 free throws and 41 rebounds. She also had 62 assists and 35 steals.
#
#
# Expected Summary: The 2008 - 09 Connecticut Huskies Women's Basketball Team had three players who scored more than 600 points: Maya Moore, Renee Montgomery and Tina Charles. Maya Moore scored 754 points, playing a total of 1209 minutes. She had 284 field goals, 90 three pointers, and 96 free throws. Montgomery Renee Montgomery scored 644 points in 1237 minutes, compiling 226 field goals, 99 three point shots and 93 free throws. Tina Charles scored 642 points in 982 minutes, with 259 field goals and 124 free throws.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 72
# |    | Date               | Label                                | Format        | Country   | Catalog     |
# |---:|:-------------------|:-------------------------------------|:--------------|:----------|:------------|
# |  0 | June 21 , 1965     | Columbia                             | Lp            | Us        | Cl 2372     |
# |  1 | June 21 , 1965     | Columbia                             | Lp            | Us        | Cs 9172     |
# |  2 | August 20 , 1965   | Cbs                                  | Lp            | Uk        | Bpg 62571   |
# |  3 | August 20 , 1965   | Cbs                                  | Lp            | Uk        | Sbpg 62571  |
# |  4 | 1970               | Columbia                             | Lp            | Us        | 465566 1    |
# |  5 | 1974               | Embassy                              | Lp            | Uk        | Emb 31057   |
# |  6 | 1974               | Cbs / Embassy                        | Lp            | Uk        | S 31503     |
# |  7 | 1975               | Cbs                                  | Lp            | Uk        | S 33645     |
# |  8 | 1987               | Columbia                             | Cd            | Us        | Ck 9172     |
# |  9 | 1989               | Cbs                                  | Cd            | Europe    | 465566 2    |
# | 10 | 1993               | Columbia                             | Cd            | Uk        | Col 468015  |
# | 11 | April 30 , 1996    | Columbia / Legacy                    | Cd            | Us        | Ck 64845    |
# | 12 | May 6 , 1996       | Columbia / Legacy                    | Cd            | Uk        | Col 483705  |
# | 13 | 1999               | Simply Vinyl                         | Lp            | Uk        | Svlp 0032   |
# | 14 | 2003               | Sony                                 | Cd            | Japan     | Mhcp - 66   |
# | 15 | 2004               | Sony / Bmg                           | Cd            | Uk        | 4837055003  |
# | 16 | February 7 , 2006  | Columbia / Mobile Fidelity Sound Lab | Sacd (Hybrid) | Us        | Udsacd 2014 |
# | 17 | February 21 , 2006 | Sundazed                             | Lp            | Us        | Lp 5197     |
# | 18 | February 10 , 2009 | Sony / Columbia                      | Cd            | Us        | 743323      |
# Query: What are the formats of the album Mr. Tambourine Man released in the US? Summarize the basic information of these releases.
#
#
# Generated Summary: Mr. Tambourine Man was released in the US in 1987, 1993, 1996, 1996 and 2009. The album was released on Columbia/Legacy and Sony/Columbia/Mobile Fidelity Sound Lab. It was released as a CD, LP, cassette, cassette and CD.
#
#
# Expected Summary: The album Mr. Tambourine Man has been released in the US in multiple formats. The original US release of the album was on Columbia Records in 1965, with catalog numbers Cl 2372 and CS 9172, both on vinyl LP. It was also reissued by Columbia in 1970 on vinyl LP with catalog number 465566 1. In 1987, a CD of the album was released by Columbia with catalog number CK 9172. Furthermore, a hybrid Super Audio CD edition was released in 2006 by Mobile Fidelity Sound Lab with catalog number UDSACD 2014. Last,on February 10 , 2009 Sony / Columbia released a CD of the album with catalog number 743323.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 185
# |    |   Year | Artist          | Album                           | Label        | Shipments (Sales)   | Certification   |
# |---:|-------:|:----------------|:--------------------------------|:-------------|:--------------------|:----------------|
# |  0 |   1976 | Eagles          | Their Greatest Hits (1971–1975) | Asylum       | 38,000,000          | 38× Platinum    |
# |  1 |   1982 | Michael Jackson | Thriller                        | Epic         | 33,000,000          | 33× Platinum    |
# |  2 |   1976 | Eagles          | Hotel California                | Asylum       | 26,000,000          | 26× Platinum    |
# |  3 |   1971 | Led Zeppelin    | Led Zeppelin IV                 | Atlantic     | 23,000,000          | 23× Platinum    |
# |  4 |   1980 | AC/DC           | Back in Black                   | Atlantic     | 22,000,000          | 22× Platinum    |
# |  5 |   1977 | Fleetwood Mac   | Rumours                         | Warner Bros. | 20,000,000          | 20× Platinum    |
# Query: How many albums achieved a certification of 20× Platinum or higher and what are the names of these albums?
#
#
# Generated Summary: There are two albums that get certification of 20× Platinum or higher. These albums are Eagles' Greatest Hits (1971-1975) and Fleetwood Mac's Rumours (1977).
#
#
# Expected Summary: A all total six album getting the certification of 20x Platinum or more high in United States. These album have Their Greatest Hits (1971-1975) from Eagles, Thriller by Michael Jackson, Hotel California also from Eagles, Led Zeppelin IV by Led Zeppelin, Back in Black by AC/DC, and Rumours by Fleetwood Mac. These famous records show some of best-selling artists and albums in U.S. music industry.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 76
# |    |   # |   Event year | Season   | Opening flag bearer    | Sport                     | Closing flag bearer   | Sport                     |
# |---:|----:|-------------:|:---------|:-----------------------|:--------------------------|:----------------------|:--------------------------|
# |  0 |  23 |         2018 | Winter   | Oleksii Bychenko       | Figure skating            | Itamar Biran          | Alpine skiing             |
# |  1 |  22 |         2016 | Summer   | Neta Rivkin            | Gymnastics                | Alona Koshevatskiy    | Gymnastics                |
# |  2 |  21 |         2014 | Winter   | Vladislav Bykanov      | Short track speed skating | Vladislav Bykanov     | Short track speed skating |
# |  3 |  20 |         2012 | Summer   | Shahar Tzuberi         | Sailing                   | Neta Rivkin           | Gymnastics                |
# |  4 |  19 |         2010 | Winter   | Alexandra Zaretsky     | Figure skating            | Mykhaylo Renzhyn      | Alpine skiing             |
# |  5 |  18 |         2008 | Summer   | Michael Kolganov       | Canoeing                  | Shahar Tzuberi        | Sailing                   |
# |  6 |  17 |         2006 | Winter   | Galit Chait            | Figure skating            | Galit Chait           | Figure skating            |
# |  7 |  16 |         2004 | Summer   | Ariel Ze'evi           | Judo                      | Gal Fridman           | Sailing                   |
# |  8 |  15 |         2002 | Winter   | Galit Chait            | Figure skating            |                       |                           |
# |  9 |  14 |         2000 | Summer   | Rogel Nachum           | Athletics                 |                       |                           |
# | 10 |  13 |         1998 | Winter   | Michael Shmerkin       | Figure skating            |                       |                           |
# | 11 |  12 |         1996 | Summer   | Lydia Hatuel-Zuckerman | Fencing                   |                       |                           |
# | 12 |  11 |         1994 | Winter   | Michael Shmerkin       | Figure skating            |                       |                           |
# | 13 |  10 |         1992 | Summer   | Eldad Amir             | Sailing                   |                       |                           |
# | 14 |   9 |         1988 | Summer   | Itzhak Yonassi         | Shooting                  |                       |                           |
# | 15 |   8 |         1984 | Summer   | Zehava Shmueli         | Athletics                 |                       |                           |
# | 16 |   7 |         1976 | Summer   | Esther Roth-Shahamorov | Athletics                 |                       |                           |
# | 17 |   6 |         1972 | Summer   | Henry Herscovici       | Shooting                  |                       |                           |
# | 18 |   5 |         1968 | Summer   | Gershon Shefa          | Swimming                  |                       |                           |
# | 19 |   4 |         1964 | Summer   | Gideon Ariel           | Athletics                 |                       |                           |
# | 20 |   3 |         1960 | Summer   | Gideon Ariel           | Athletics                 |                       |                           |
# | 21 |   2 |         1956 | Summer   | Yoav Ra'anan           | Diving                    |                       |                           |
# | 22 |   1 |         1952 | Summer   | Abraham Shneior        | Basketball                |                       |                           |
# Query: Has there been an instance where the same athlete was the opening and closing flag bearer for Israel in a single Olympics event, if yes, can you provide details?
#
#
# Generated Summary: There is one instance where the same athlete was the opening and closing flag bearer for Israel in a single Olympics event. This happened in the 2012 Summer Olympics, with Shahar Tzuberi being the opening flag bearer and Mykhaylo Renzhyn being the closing flag bearer.
#
#
# Expected Summary: Yes, there has be two time when same athlete is opening and closing flag bearer for Israel in one Olympics event. In 2014 Winter Olympics, Vladislav Bykanov is both opening and closing flag bearer for Israel, he do short track speed skating sport. In 2006 Winter Olympics, Galit Chait is both opening and closing flag bearer for Israel, he do figure skating sport.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 150
# |    |   Game# | Date             | Result                                  | Attendance   | Notes                                                                                               |
# |---:|--------:|:-----------------|:----------------------------------------|:-------------|:----------------------------------------------------------------------------------------------------|
# |  0 |       1 | 18 January 1930  | Australia def. Wales 26–10              | 20,000       | 1929–30 Kangaroo Tour                                                                               |
# |  1 |       2 | 30 December 1933 | Australia def. Wales 51–19              | 10,000       | 1933–34 Kangaroo Tour                                                                               |
# |  2 |       3 | 12 March 1949    | France def. England 12–5                | 15,000       | 1948–49 European Rugby League Championship First French national team (any sport) to win at Wembley |
# |  3 |       4 | 16 October 1963  | Australia def. Great Britain 22–16      | 13,946       | 1963 Ashes series                                                                                   |
# |  4 |       5 | 3 November 1973  | Great Britain def. Australia 21–12      | 9,874        | 1973 Ashes series                                                                                   |
# |  5 |       6 | 27 October 1990  | Great Britain def. Australia 19–12      | 54,569       | 1990 Ashes series                                                                                   |
# |  6 |       7 | 24 October 1992  | Australia def. Great Britain 10–6       | 73,631       | 1992 Rugby League World Cup Final New international rugby league attendance record.                 |
# |  7 |       8 | 16 October 1993  | Great Britain def. New Zealand 17–0     | 36,131       | 1993 Great Britain vs New Zealand series                                                            |
# |  8 |       9 | 22 October 1994  | Great Britain def. Australia 8–4        | 57,034       | 1994 Ashes series                                                                                   |
# |  9 |      10 | 7 October 1995   | England def. Australia 20–16            | 41,271       | 1995 Rugby League World Cup Group A                                                                 |
# | 10 |      11 | 28 October 1995  | Australia def. England 16–8             | 66,540       | 1995 Rugby League World Cup Final                                                                   |
# | 11 |      12 | 1 November 1997  | Australia (SL) def. Great Britain 38–14 | 41,135       | 1997 Super League Test series                                                                       |
# Query: How did the attendance number vary with respect to different international Rugby League matches held in the Wembley Stadium between 1930 and 1997?
#
#
# Generated Summary: The attendance number for international Rugby League matches held in Wembley Stadium between 1930 and 1997 vary a lot. In 1930, Australia beat Wales 26-10 in the 1929-30 Kangaroo Tour, but in 1933, Australia lost to Wales 51-19 in the 1933-34 Kangaroo Tours. In 1949, France beat England 12-5 in the 1948-49 European Rugby League Championship First French national team (any sport) game. But, in 1963, Australia lose to Great Britain 22-16 in the 1963 Ashes series, and in 1973, Great Britain beat Australia 21-12 in the Ashes series. In 1994, Great
#
#
# Expected Summary: The number of people for international Rugby League matches at Wembley Stadium from 1930 to 1997 had big changes. The lowest people was 9,874 in the 1973 Ashes series where Great Britain won against Australia, while the highest people was at the 1992 Rugby League World Cup Final, with 73,631 people watching Australia win against Great Britain. In all the years, matches with Australia and Great Britain usually had more people, like in the 1990 Ashes series with 54,569 people and the 1994 Ashes series with 57,034 people. But, there were times not like this, like the 1933-34 Kangaroo Tour match between Australia and Wales, which had much lower people of 10,000.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 148
# |    |   Constituency No | Name of the Constituencies                  | Electoral Population   | Ethnic Representants   |    |
# |---:|------------------:|:--------------------------------------------|:-----------------------|:-----------------------|:---|
# |  0 |                 1 | Grand River North West and Port Louis West  | 40,572                 | Mauritian              |    |
# |  1 |                 2 | Port Louis South and Port Louis Central     | 24,642                 | Mauritian              |    |
# |  2 |                 3 | Port Louis Maritime and Port Louis East     | 22,488                 | Mauritian              |    |
# |  3 |                 4 | Port Louis North and Montagne Longue        | 46,179                 | Mauritian              |    |
# |  4 |                 5 | Pamplemousses and Triolet                   | 56,620                 | Mauritian              |    |
# |  5 |                 6 | Grand Baie and Poudre d'Or                  | 48,379                 | Mauritian              |    |
# |  6 |                 7 | Piton and Riviere du Rempart                | 40,624                 | Mauritian              |    |
# |  7 |                 8 | Quartier Militaire and Moka                 | 41,342                 | Mauritian              |    |
# |  8 |                 9 | Flacq and Bon Acceuil                       | 50,883                 | Mauritian              |    |
# |  9 |                10 | Montagne Blanche and Grand River South East | 47,296                 | Mauritian              |    |
# | 10 |                11 | Vieux Grand Port and Rose Belle             | 39,432                 | Mauritian              |    |
# | 11 |                12 | Mahebourg and Plaine Magnien                | 36,242                 | Mauritian              |    |
# | 12 |                13 | Riviere des Anguilles and Souillac          | 33,169                 | Mauritian              |    |
# | 13 |                14 | Savanne and Black River                     | 58,341                 | Mauritian              |    |
# | 14 |                15 | La Caverne and Phoenix                      | 53,548                 | Mauritian              |    |
# | 15 |                16 | Vacoas and Floreal                          | 44,053                 | Mauritian Mauritian    |    |
# | 16 |                17 | Curepipe and Midlands                       | 45,346                 | Mauritian Mauritian    |    |
# | 17 |                18 | Belle Rose and Quatre Bornes                | 42,173                 | Mauritian Mauritian    |    |
# | 18 |                19 | Stanley and Rose Hill                       | 38,982                 | Mauritian              |    |
# | 19 |                20 | Beau Bassin and Petite Riviere              | 42,656                 | Mauritian Mauritian    |    |
# | 20 |                21 | Rodrigues                                   | 26,930                 | Mauritian              |    |
# Query: What is the connection, if any, between the size of the electoral population and the number of ethnic representatives in the different constituencies?
#
#
# Generated Summary: The big number of people in the electoral constituency of Savanne and Black River, show that there is a connection between the number of voters and the number ethnic representatives in the constituency. This connection is seen in the number and number of ethnic representatives, as the number in Savanne-Black River is 58,341, while the number for Pamplemousses and Triolet is 56,620 and the total number of Ethnic Representants is 56
#
#
# Expected Summary: From table data, seem no relation between electoral population size and count of ethnic representative in different area. All areas in list, no matter their electoral population size, write "Mauritian" as ethnic representative, show same ethnic in all area. This mean ethnic representative count not different by electoral population size in Mauritius areas.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 168
# |    | Season   | Series                              | Team                       |   Races |   Wins |   Poles |   FLaps |   Podiums | Points   | Position   |
# |---:|:---------|:------------------------------------|:---------------------------|--------:|-------:|--------:|--------:|----------:|:---------|:-----------|
# |  0 | 2013     | Ginetta Junior Championship         | JHR Developments           |      20 |      0 |       0 |       0 |         7 | 221      | 10th       |
# |  1 | 2014     | Ginetta Junior Championship         | JHR Developments           |      20 |      0 |       0 |       0 |         5 | 287      | 8th        |
# |  2 | 2015     | British GT Championship             | Beechdean-AMR              |       7 |      2 |       0 |       0 |         5 | 164.5    | 1st        |
# |  3 | 2016     | British GT Championship             | Generation AMR SuperRacing |       6 |      0 |       0 |       0 |         0 | 29       | 15th       |
# |  4 | 2017     | BRDC British Formula 3 Championship | Double R Racing            |      24 |      0 |       0 |       0 |         1 | 264      | 9th        |
# |  5 | 2018     | BRDC British Formula 3 Championship | Douglas Motorsport         |      24 |      1 |       0 |       0 |         2 | 260      | 8th        |
# |  6 | 2018-19  | MRF Challenge                       | N/A                        |      15 |      6 |       0 |       5 |         9 | 280      | 1st        |
# |  7 | 2019     | F3 Asian Championship               | Seven GP                   |       3 |      0 |       0 |       0 |         0 | 18*      | 7th*       |
# |  8 | 2019     | W Series                            | Hitech                     |       0 |      0 |       0 |       0 |         0 | 0*       | N/A*       |
# Query: Throughout Jamie Chadwick's career, which season was the least successful for her in terms of point accumulation, number of wins, and overall position? What series was she contesting in and which team was she a part of during this season?
#
#
# Generated Summary: Jamie Chadwick's least successful season in terms of point accumulation, number of wins, and overall position was in 2013, when she was 10th in the Ginetta Junior Championship. She was part of JHR Developments team during this season. In 2014, she was 8th in Ginetta junior championship, and in 2016, she finished 15th in British GT Championship. In 2017, she had 264 points and finished 9th in BRDC British Formula 3 Championship.
#
#
# Expected Summary: In Jamie Chadwick career, the not good season for her about point get, number of win, and all position was in year 2016. She was in British GT Championship that year and her team was Generation AMR SuperRacing. In this time, Chadwick get only 29 points, not have any win, and her position was number 15.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 125
# |    |   # | Event Title     | Date               | Arena               | Location                  | Attendees   | Broadcast                        |
# |---:|----:|:----------------|:-------------------|:--------------------|:--------------------------|:------------|:---------------------------------|
# |  0 |  19 | Dynamite!! 2010 | December 31, 2010  | Saitama Super Arena | Saitama, Saitama, Japan   | 26,729      | Tokyo Broadcasting System; HDNet |
# |  1 |  18 | Dream 16        | September 25, 2010 | Nippon Gaishi Hall  | Nagoya, Aichi, Japan      | 9,304       | Tokyo Broadcasting System; HDNet |
# |  2 |  17 | Dream 15        | Jul 10, 2010       | Saitama Super Arena | Saitama, Saitama, Japan   | 13,028      | Tokyo Broadcasting System; HDNet |
# |  3 |  16 | Dream 14        | May 29, 2010       | Saitama Super Arena | Saitama, Saitama, Japan   | 12,712      | Tokyo Broadcasting System; HDNet |
# |  4 |  15 | Dream 13        | March 22, 2010     | Yokohama Arena      | Yokohama, Kanagawa, Japan | 13,712      | Tokyo Broadcasting System; HDNet |
# Query: How many times was the Saitama Super Arena chosen as the location for DREAM events in 2010?
#
#
# Generated Summary: In 2010, Saitama Super Arena was chosen as the location for three DREAM events. The first event was Dynamite!! 2010 on December 31, 2010, followed by Dream 15 on July 10, 2010 and Dream 14 on May 29, 2010.
#
#
# Expected Summary: In 2010, the Saitama Super Arena be choose for DREAM events three time. These events have Dynamite!! 2010 on December 31, Dream 15 on July 10, and Dream 14 on May 29. Other event place for that year was Nippon Gaishi Hall in Nagoya and Yokohama Arena in Yokohama, for Dream 16 and Dream 13, respective.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 38
# |    |   Game | Date    | Opponent             | Result   |   Bills Points |   Opponents |   Bills First Downs | Record   |
# |---:|-------:|:--------|:---------------------|:---------|---------------:|------------:|--------------------:|:---------|
# |  0 |      1 | Sept 16 | New England Patriots | Win      |             31 |          13 |                  23 | 1 - 0    |
# |  1 |      2 | Sept 23 | San Diego Chargers   | Loss     |              7 |          34 |                  16 | 1 - 1    |
# |  2 |      3 | Sept 30 | New York Jets        | Win      |              9 |           7 |                  15 | 2 - 1    |
# |  3 |      4 | Oct 7   | Philadelphia Eagles  | Win      |             27 |          26 |                  16 | 3 - 1    |
# |  4 |      5 | Oct 14  | Baltimore Colts      | Win      |             31 |          13 |                  18 | 4 - 1    |
# |  5 |      6 | Oct 21  | Miami Dolphins       | Loss     |              6 |          27 |                   8 | 4 - 2    |
# |  6 |      7 | Oct 29  | Kansas City Chiefs   | Win      |             23 |          14 |                  21 | 5 - 2    |
# |  7 |      8 | Nov 4   | New Orleans Saints   | Loss     |              0 |          13 |                  10 | 5 - 3    |
# |  8 |      9 | Nov 11  | Cincinnati Bengals   | Loss     |             13 |          16 |                  10 | 5 - 4    |
# |  9 |     10 | Nov 18  | Miami Dolphins       | Loss     |              0 |          17 |                  15 | 5 - 5    |
# | 10 |     11 | Nov 25  | Baltimore Colts      | Win      |             24 |          17 |                  16 | 6 - 5    |
# | 11 |     12 | Dec 2   | Atlanta Falcons      | Win      |             17 |           6 |                  17 | 7 - 5    |
# | 12 |     13 | Dec 9   | New England Patriots | Win      |             37 |          13 |                  13 | 8 - 5    |
# Query: Summarize the game(s) in which Buffalo Bills achieved the highest point.
#
#
# Generated Summary: The Buffalo Bills achieved the highest point in their season on Dec 9, 2008, against the New England Patriots. The Bills scored 37 points, which was 13 more than their opponents. This was the highest total of any Bills game that season.
#
#
# Expected Summary: In their thirteenth game on December 9th against the New England Patriots, the Buffalo Bills achieved their highest point total of the season with a win of 37-13. The Bills's defense only allowed 13 points from their opponent. This gave the Bills a record at that time of 8-5.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 114
# |    |   No. overall |   No. in season | Title                    | Directed by           | Written by                 | Original air date   | Prod. code   |   US viewers (millions) |
# |---:|--------------:|----------------:|:-------------------------|:----------------------|:---------------------------|:--------------------|:-------------|------------------------:|
# |  0 |            85 |               1 | "The End"                | Bradley Buecker       | Ryan Murphy & Brad Falchuk | September 12, 2018  | 8ATS01       |                    3.08 |
# |  1 |            86 |               2 | "The Morning After"      | Jennifer Lynch        | James Wong                 | September 19, 2018  | 8ATS02       |                    2.21 |
# |  2 |            87 |               3 | "Forbidden Fruit"        | Loni Peristere        | Manny Coto                 | September 26, 2018  | 8ATS03       |                    1.95 |
# |  3 |            88 |               4 | "Could It Be... Satan?"  | Sheree Folkson        | Tim Minear                 | October 3, 2018     | 8ATS04       |                    2.02 |
# |  4 |            89 |               5 | "Boy Wonder"             | Gwyneth Horder-Payton | John J. Gray               | October 10, 2018    | 8ATS05       |                    2.12 |
# |  5 |            90 |               6 | "Return to Murder House" | Sarah Paulson         | Crystal Liu                | October 17, 2018    | 8ATS06       |                    2.01 |
# |  6 |            91 |               7 | "Traitor"                | Jennifer Lynch        | Adam Penn                  | October 24, 2018    | 8ATS07       |                    1.85 |
# |  7 |            92 |               8 | "Sojourn"                | Bradley Buecker       | Josh Green                 | October 31, 2018    | 8ATS08       |                    1.63 |
# |  8 |            93 |               9 | "Fire and Reign"         | Jennifer Arnold       | Asha Michelle Wilson       | November 7, 2018    | 8ATS09       |                    1.65 |
# |  9 |            94 |              10 | "Apocalypse Then"        | Bradley Buecker       | Ryan Murphy & Brad Falchuk | November 14, 2018   | 8ATS10       |                    1.83 |
# Query: Who are the directors and writers involved in the first and last episodes of season 8 of American Horror Story, and what are the US viewer numbers for these episodes?
#
#
# Generated Summary: The directors and writers involved in first and last episodes of season 8 of American Horror Story are Bradley Buecker and Jennifer Lynch. The first episode, titled "The End," is directed by Bueck and written by Ryan Murphy & Brad Falchuk. The last episode, called "Apocalypse Then," is also directed by Bradley Bucker and written also by Ryan and Brad Falchuck. The US viewer numbers for these episodes are 3.08 million and 1.83 million, respectively.
#
#
# Expected Summary: First episode of season 8 American Horror Story, name "The End," was directed by Bradley Buecker and write by Ryan Murphy & Brad Falchuk, got 3.08 million US peoples watch. Last episode of the season, name "Apocalypse Then," also directed by Bradley Buecker and write by Ryan Murphy & Brad Falchuk, get 1.83 million US peoples watch. Both episodes have same directors and writers but have different number of watch peoples.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 137
# |    | Player        | Country       | Year(s) won      |   R1 |   R2 |   R3 |   R4 |   Total | To par   | Finish   |
# |---:|:--------------|:--------------|:-----------------|-----:|-----:|-----:|-----:|--------:|:---------|:---------|
# |  0 | Lou Graham    | United States | 1975             |   72 |   71 |   68 |   68 |     279 | −1       | 2        |
# |  1 | Jack Nicklaus | United States | 1962, 1967, 1972 |   74 |   68 |   71 |   72 |     285 | +5       | T10      |
# |  2 | Gary Player   | South Africa  | 1965             |   72 |   67 |   71 |   75 |     285 | +5       | T10      |
# |  3 | Arnold Palmer | United States | 1960             |   70 |   72 |   73 |   72 |     287 | +7       | T19      |
# |  4 | Lee Trevino   | United States | 1968, 1971       |   74 |   70 |   73 |   73 |     290 | +10      | T27      |
# |  5 | Johnny Miller | United States | 1973             |   71 |   73 |   70 |   76 |     290 | +10      | T27      |
# |  6 | Hale Irwin    | United States | 1974             |   73 |   71 |   77 |   72 |     293 | +13      | T41      |
# Query: Who had the lowest total score in the 1977 U.S. Open, and how did his scoring pattern fluctuate over the course of the four rounds?
#
#
# Generated Summary: The lowest total score in 1977 U.S. Open was 293, with a total score of 73. This score show that he had a very low scoring performance over the course of the four rounds.
#
#
# Expected Summary: In 1977 US Open, Lou Graham got lowest total score 279. His scoring pattern change in four rounds, begin with first round score 72 and decrease to 71 in second round. In last two rounds, Graham show very consistent, got 68 score in third and fourth rounds, finally finish event at good -1 under par.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 123
# |    |   Rank | Name                                     | Height feet / m   |   Floors |   Year | Image                                                                                                                                                  | Notes                                     |
# |---:|-------:|:-----------------------------------------|:------------------|---------:|-------:|:-------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------|
# |  0 |      1 | Robert E. Coyle United States Courthouse | 225 / 69          |        9 |   2005 | Tallest building in Fresno. Tallest building completed in the 2000s.                                                                                   | -                                         |
# |  1 |      2 | Fresno Pacific Towers                    | 219 / 67          |       15 |   1925 | Historically called the Pacific Southwest Building and the Security Bank Building. Tallest building between Oakland and Los Angeles from 1923 to 1963. | -                                         |
# |  2 |      3 | Golden State County Plaza                | 216 / 66          |       21 |   1964 | Historically called the Del Webb Building. Tallest building between Oakland and Los Angeles from 1963 to 1971.                                         | Golden State County Plaza, Fresno, CA.JPG |
# |  3 |      4 | The Grand 1401                           | 173 / 53          |       11 |   1923 | Historically called the San Joaquin Light and Power Building, the PG&E Building, and the International Trade Center.                                   | The Grand 1401, Fresno, CA.JPG            |
# |  4 |      5 | Tower at Convention Center Court         | 160 / 49          |       11 |   2003 |                                                                                                                                                        | Tower at Covention Center.JPG             |
# |  5 |      6 | Mattei Building                          | 150 / 46          |       12 |   1921 | Historically called the Guarantee Savings Building.                                                                                                    |                                           |
# |  6 |      7 | Hotel Californian                        | 137 / 42          |        9 |   1923 |                                                                                                                                                        |                                           |
# |  7 |      8 | Helm Building                            | 124 / 38          |       10 |   1914 |                                                                                                                                                        | Helm Building Fresno CA.JPG               |
# |  8 |      9 | Bank of Italy                            | 124 / 38          |        8 |   1918 |                                                                                                                                                        | -                                         |
# |  9 |     10 | Community Regional Medical Center        | 121 / 37          |       10 |   1972 |                                                                                                                                                        |                                           |
# Query: What is the relationship between the number of floors and the building's height in Fresno's tallest buildings? Analyze the data included in the table in relation to this relationship.
#
#
# Generated Summary: The table show that the number of floors and the building's height in Fresno's tallest buildings has a positive relation. The number of floor is higher when the building is taller, as shown by the table. For example, the Robert E. Coyle United States Courthouse, which stands at 225 feet (69 meters) tall, has 9 floors, making it the tallest building in Fresno. However, the number and height of the building in the 2000s have a negative relation, as the table show the building was completed in the 1970s, but still not the tallest in the city. This shows that the relationship between the
#
#
# Expected Summary: The relation between number of floors and building height in tallest buildings in Fresno mostly positive. It means when floors more, building height also more. But this relation not always straight line because other things can affect building height, like each floor's height. For example, Golden State County Plaza has 21 floors but not tallest building in Fresno. It because its total height less than Robert E. Coyle United States Courthouse. This building only has 9 floors but higher total height.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 88
# |    | City        | August Rainfall (mm)   |   Rainfall (in) | September Rainfall (mm)   |   Rainfall (in) | Total Rainfall (mm)   |   Total Rainfall (in) | Notes   | References   |
# |---:|:------------|:-----------------------|----------------:|:--------------------------|----------------:|:----------------------|----------------------:|:--------|:-------------|
# |  0 | Mithi       | 530*                   |            21   | 760*                      |            30   | 1290*                 |                  51   |         |              |
# |  1 | Mirpur Khas | 263.1*                 |            10.3 | 603*                      |            23.7 | 866.1*                |                  34.1 |         |              |
# |  2 | Nawabshah   | 275.2*                 |            10.8 | 353.2*                    |            13.9 | 628.4*                |                  24.7 |         |              |
# |  3 | Badin       | 331.2*                 |            13   | 284.1                     |            11.1 | 615.3*                |                  24.2 |         |              |
# |  4 | Chhor       | 276                    |            10.9 | 268                       |            10.6 | 544*                  |                  21.4 |         |              |
# |  5 | Dadu        | 134.1                  |             5.2 | 348.1                     |            13.7 | 482.2*                |                  18.9 |         |              |
# |  6 | Padidan     | 251.2                  |             9.8 | 172                       |             6.8 | 423.2*                |                  16.6 |         |              |
# |  7 | Hyderabad   | 162.2                  |             6.3 | 244.2                     |             9.6 | 406.4                 |                  16   |         |              |
# |  8 | Karachi     | 61.2                   |             2.4 | 212.2                     |             8.3 | 273.3                 |                  10.7 |         |              |
# Query: What does the total rainfall data for the cities mentioned in the table suggest about the severity of the floods in different locations?
#
#
# Generated Summary: The total rainfall data for the cities mentioned in the table show that the floods in different areas of Sindh were very serious. Mithi, Mirpur Khas, Nawabshah, Badin, Chhor, Dadu, Padidan, Hyderabad, and Karachi all had a total of 1290.0 and 1290, respectively.
#
#
# Expected Summary: The all rain data for city in table show that flood badness different at many places in Sindh. Cities like Mithi, Mirpur Khas, and Nawabshah have very big rain, with all rain 51.0 inch, 34.1 inch, and 24.7 inch, so maybe these areas have most bad flood compare to other place with less rain total.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 85
# |    |   No. overall |   No. in season | Title       | Team Test                                  | Reviews/Drives                                                                                                                                                | Original air date   |
# |---:|--------------:|----------------:|:------------|:-------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------|
# |  0 |           248 |               1 | "Episode 1" | DS 7 Crossback (21/40)                     | Mercedes AMG C63 vs. Alfa Romeo Giulia Quadrifoglio • Jonny tests the new London Taxi LEVC TX • Second Hand Cars: BMW M5 & Mercedes E 55 AMG & Audi RS 6      | 6 September 2018    |
# |  1 |           249 |               2 | "Episode 2" | Nissan Leaf Tekna 110kw (19/40)            | Alfa Romeo Stelvio vs. Jaguar F-Pace • Jonny at Kia Proving Grounds in Kia Stinger GT • Bentley Continental GT                                                | 13 September 2018   |
# |  2 |           250 |               3 | "Episode 3" | Mercedes X250 d (22.5/40)                  | Honda Civic Type R vs. Audi S3 Sportback vs.                                                                                                                  | 20 September 2018   |
# |  3 |           251 |               4 | "Episode 4" | Dacia Duster Comfort SCe 115 4x2 (25/40)   | Caravan vs. Campervan (Mercedes-Benz Marco Polo) • Audi S5 Coupe vs.                                                                                          | 27 September 2018   |
# |  4 |           252 |               5 | "Episode 5" | Alpine A110 (27/40)                        | Range Rover Sport SVR vs. Bentley Bentayga • Jason investigates the Ultra Low Emission Zone • Second Hand Cars: Volvo XC90 & Land Rover Discovery 3 & Audi Q7 | 4 October 2018      |
# |  5 |           253 |               6 | "Episode 6" | Vauxhall Insignia GSi Sport Tourer (18/40) | Nissan GT-R NISMO vs. Porsche 911 GT3 RS • VW Polo GTI vs.                                                                                                    | 11 October 2018     |
# ...
# |  4 |   2015 | Eleanor Lathram      | Manchester  |     16 |                              |                                   |                                                                                                                          |
# |  5 |   2014 | Mikaela Seamans      | Keene       |     17 |                              |                                   |                                                                                                                          |
# |  6 |   2013 | Kelsea Campbell      | Auburn      |     17 |                              |                                   |                                                                                                                          |
# |  7 |   2012 | Marisa DeLuca        | Windham     |     18 |                              |                                   |                                                                                                                          |
# |  8 |   2011 | Annie Read           | Sandwich    |     17 |                              |                                   |                                                                                                                          |
# |  9 |   2010 | Morgan Lucas         | Manchester  |     18 |                              |                                   |                                                                                                                          |
# | 10 |   2009 | Amber Faucher        | Pelham      |     17 |                              |                                   | Later Miss New Hampshire USA 2013                                                                                        |
# | 11 |   2008 | Courtney Morgan      | Manchester  |     18 | Top 15                       |                                   |                                                                                                                          |
# | 12 |   2007 | Alexandra MacDonald  | Gilford     |     18 |                              |                                   |                                                                                                                          |
# | 13 |   2006 | Camille Westbrooks   | Salem       |     18 |                              |                                   | Miss Petite Teen North America 2004, Miss Sunburst USA 2005                                                              |
# | 14 |   2005 | Brittany Dube        | Hampstead   |     15 |                              |                                   |                                                                                                                          |
# | 15 |   2004 | Brittany Freeman     | Merrimack   |     16 |                              |                                   | Cheerleader for the Miami Dolphins; Daughter of Miss New Hampshire USA 1977 & Miss New Hampshire 1978- Belinda Bridgeman |
# | 16 |   2003 | Marshele Lee         | Manchester  |     16 |                              |                                   |                                                                                                                          |
# | 17 |   2002 | Jennifer Stein       | Manchester  |     18 |                              |                                   |                                                                                                                          |
# | 18 |   2001 | Ashley Blair         | Manchester  |     15 |                              |                                   |                                                                                                                          |
# | 19 |   2000 | Kristen O'Neil       | Manchester  |     17 |                              |                                   | Cheerleader for the New England Patriots                                                                                 |
# | 20 |   1999 | Kristin Thurston     | Manchester  |     17 |                              |                                   |                                                                                                                          |
# | 21 |   1998 | Nadiyah Humber       | Salem       |     16 |                              |                                   |                                                                                                                          |
# | 22 |   1997 | Bonnie Gagnon        | Manchester  |     18 |                              |                                   |                                                                                                                          |
# | 23 |   1996 | Melissa Coish        | Manchester  |     16 |                              |                                   |                                                                                                                          |
# | 24 |   1995 | Denise Courtney Hill | Manchester  |     16 |                              |                                   |                                                                                                                          |
# | 25 |   1994 | Keri Lynn Pratt      | Derry       |     16 |                              |                                   | Television and movie actress.                                                                                            |
# | 26 |   1993 | Gretchen Durgin      | Lancaster   |     17 |                              |                                   | Later Miss New Hampshire USA 1997                                                                                        |
# | 27 |   1992 | Angela Etter         | Gorham      |     15 |                              |                                   |                                                                                                                          |
# | 28 |   1991 | Janel Bishop         | Manchester  |     17 | Miss Teen USA 1991           |                                   |                                                                                                                          |
# | 29 |   1990 | Sarah McFall         | Manchester  |     16 |                              |                                   |                                                                                                                          |
# | 30 |   1989 | Kerri Sossei         | Londonderry |     15 |                              |                                   |                                                                                                                          |
# | 31 |   1988 | Christa Jones        | Keene       |     17 |                              |                                   |                                                                                                                          |
# | 32 |   1987 | Cara Daras           | Nashua      |     17 |                              |                                   |                                                                                                                          |
# | 33 |   1986 | Diane Dothan         | Rochester   |     17 |                              |                                   |                                                                                                                          |
# | 34 |   1985 | Katherine Borski     | Londonderry |     16 |                              |                                   |                                                                                                                          |
# | 35 |   1984 | Lisa Fernald         | Hampton     |     15 |                              |                                   |                                                                                                                          |
# | 36 |   1983 | Maureen Murray       | Manchester  |     18 |                              |                                   | Later Miss New York USA 1991, finished 7th at Miss USA 1991                                                              |
# Query: Which hometown produced the most winners in the Miss New Hampshire Teen USA competition based on the available data, and how might this trend or result be interpreted?
#
#
# Generated Summary: Manchester has most winners in Miss New Hampshire Teen USA competition, with five winners. This trend can be seen from the table, which show that Manchester has most successful place in competition.
#
#
# Expected Summary: According to available data, Manchester produced most winners in Miss New Hampshire Teen USA competition, with total of 14 winners. This trend maybe shows Manchester has more big group of talented and accomplished young women, maybe because have more people or better chances for grow in confidence, skills and education. Another option, maybe because more organized or well-made pageant community or training program in city, which make contestants more prepared for succeed in competition.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 30
# |    | Rank   | Name                 | Nationality                | # 1   | # 2   |   # 3 | # 4   | # 5   | # 6   |   Mark | Notes   |
# |---:|:-------|:---------------------|:---------------------------|:------|:------|------:|:------|:------|:------|-------:|:--------|
# |  0 |        | Paweł Fajdek         | Poland (POL)               | 76.40 | x     | 80.64 | 80.88 | 79.34 | 78.29 |  80.88 |         |
# |  1 |        | Dilshod Nazarov      | Tajikistan (TJK)           | 76.83 | 77.61 | 76.17 | 78.06 | 78.55 | 76.60 |  78.55 |         |
# |  2 |        | Wojciech Nowicki     | Poland (POL)               | 76.14 | 76.73 | 77.2  | x     | 75.80 | 78.55 |  78.55 |         |
# |  3 | 4      | Krisztián Pars       | Hungary (HUN)              | 76.33 | 75.98 | 77.32 | x     | 76.40 | 77.05 |  77.32 |         |
# |  4 | 5      | Sergej Litvinov      | Russia (RUS)               | 70.75 | 77.09 | 77.24 | x     | 77.04 | x     |  77.24 | SB      |
# |  5 | 6      | David Söderberg      | Finland (FIN)              | 76.92 | 74.75 | 75.7  | 75.48 | 75.32 | 75.19 |  76.92 | SB      |
# |  6 | 7      | Mostafa Al-Gamel     | Egypt (EGY)                | 74.70 | 76.25 | 76.81 | x     | x     | 75.77 |  76.81 |         |
# |  7 | 8      | Marcel Lomnický      | Slovakia (SVK)             | 73.71 | 74.36 | 75.62 | 75.79 | 75.72 | 74.82 |  75.79 |         |
# |  8 | 9      | Ashraf Amgad Elseify | Qatar (QAT)                | x     | 72.90 | 74.09 |       |       |       |  74.09 |         |
# |  9 | 10     | Tuomas Seppänen      | Finland (FIN)              | x     | 71.85 | 73.18 |       |       |       |  73.18 |         |
# | 10 | 11     | Nick Miller          | Great Britain & N.I. (GBR) | x     | x     | 72.94 |       |       |       |  72.94 |         |
# | 11 | 12     | Roberto Janet        | Cuba (CUB)                 | x     | 72.50 | 71.79 |       |       |       |  72.5  |         |
# Query: How many performers had invalid throws in one or more of their attempts, marked by 'x', and who were they?
#
#
# Generated Summary: There were four performers who had invalid throw in one or more of their attempts, marked by 'x' in table. These performers were Paweł Fajdek, Dilshod Nazarov, Wojciech Nowicki, Krisztián Pars, Sergej Litvinov, and Mostafa Al-Gamel.
#
#
# Expected Summary: A total of 9 performers had invalid throws in one or more of their attempts, and they are Paweł Fajdek, Wojciech Nowicki, Krisztián Pars, Sergej Litvinov, Mostafa Al-Gamel, Ashraf Amgad Elseify, Tuomas Seppänen, Nick Miller, and Roberto Janet.
# ----------------------------------------------------------------------------------------------------
#
#
# Index: 63
# |    |   No. overall |   No. in season | Title                | Directed by           | Written by                         | Original air date   |   Prod. code |   US viewers (millions) |
# |---:|--------------:|----------------:|:---------------------|:----------------------|:-----------------------------------|:--------------------|-------------:|------------------------:|
# |  0 |           103 |               1 | "Hangman"            | Ken Sanzel            | Ken Sanzel                         | September 25, 2009  |          601 |                    8.1  |
# |  1 |           104 |               2 | "Friendly Fire"      | Rod Holcomb           | Mark Llewellyn & Robert David Port | October 2, 2009     |          602 |                    7.85 |
# |  2 |           105 |               3 | "7 Men Out"          | Alex Zakrzewski       | Don McGill                         | October 9, 2009     |          603 |                    7.34 |
# |  3 |           106 |               4 | "Where Credit's Due" | Dennis Smith          | Andy Dettmann                      | October 16, 2009    |          604 |                    7.77 |
# |  4 |           107 |               5 | "Hydra"              | Ralph Hemecker        | Sean Crouch                        | October 23, 2009    |          605 |                    8.05 |
# |  5 |           108 |               6 | "Dreamland"          | Stephen Gyllenhaal    | Nicolas Falacci & Cheryl Heuton    | October 30, 2009    |          606 |                    7.74 |
# |  6 |           109 |               7 | "Shadow Markets"     | Julie Hébert          | Julie Hébert                       | November 6, 2009    |          607 |                    8.09 |
# |  7 |           110 |               8 | "Ultimatum"          | Dennis Smith          | Robert David Port                  | November 13, 2009   |          608 |                    8.16 |
# |  8 |           111 |               9 | "Con Job"            | Ralph Hemecker        | Don McGill                         | November 20, 2009   |          609 |                    7.84 |
# |  9 |           112 |              10 | "Old Soldiers"       | Ken Sanzel            | Steve Cohen                        | December 4, 2009    |          610 |                    7.38 |
# | 10 |           113 |              11 | "Scratch"            | Stephen Gyllenhaal    | Mary Leah Sutton                   | January 8, 2010     |          611 |                    9.32 |
# | 11 |           114 |              12 | "Arm in Arms"        | Gwyneth Horder-Payton | Andy Dettmann                      | January 15, 2010    |          612 |                    9.65 |
# | 12 |           115 |              13 | "Devil Girl"         | Stephen Gyllenhaal    | Julie Hébert                       | January 29, 2010    |          613 |                    8.7  |
# | 13 |           116 |              14 | "And the Winner Is…" | Ralph Hemecker        | Gary Rieck                         | February 5, 2010    |          614 |                    9.18 |
# | 14 |           117 |              15 | "Growin' Up"         | Rob Morrow            | Robert Port                        | March 5, 2010       |          615 |                    8.1  |
# | 15 |           118 |              16 | "Cause and Effect"   | Nicolas Falacci       | Nicolas Falacci & Cheryl Heuton    | March 12, 2010      |          616 |                    8.74 |
# Query: How many episodes were written and directed by the same person?
#
#
# Generated Summary: The show has two episodes written and directed by same person. In season 4, "Growin' Up" and "Ultimatum" are directed by Rob Morrow and Dennis Smith.
#
#
# Expected Summary: In Season 6 of Numbers, have three episode that same person write and direct. These episodes are "Hangman" by Ken Sanzel, "Shadow Markets" by Julie Hébert, and "Cause and Effect" by Nicolas Falacci.
# ----------------------------------------------------------------------------------------------------
